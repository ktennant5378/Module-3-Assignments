# %% [markdown]
# # **Week 5: Feature Selection and Regularization on the Ames Housing Dataset**
#
# In last week’s homework, you built and evaluated linear regression models with increasingly rich feature sets. This week, we take the next critical step: **deciding which features to keep—and how much complexity is too much**.
#
# In real-world modeling, adding more predictors does not automatically lead to better models. Extra features can increase variance, reduce interpretability, and hurt generalization. This homework explores two complementary strategies for controlling model complexity:
#
# * **Feature selection**, where we explicitly choose a subset of predictors
# * **Regularization**, where we keep all predictors but constrain their influence
#
# Specifically, you will experiment with:
#
# * **Forward Selection**
# * **Backward Selection**
# * **Ridge Regression**
#
# Forward and backward selection approach the same problem from opposite directions—one builds a model up feature by feature, while the other prunes features away—and because both are greedy algorithms, they may arrive at different solutions. In contrast, ridge regression does not discard features at all; instead, it keeps all predictors but shrinks their coefficients toward zero, reducing model complexity in a continuous rather than discrete way.
#
# Comparing these methods highlights an important modeling choice: whether to simplify a model by selecting features explicitly or by regularizing their influence, and how these different strategies affect generalization performance.
#
# There are **4 problems** with **8 graded answers** worth **6 points each**, and you receive **7 points for completion**.

# %%
# Useful imports

import os
import kagglehub
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import io
import zipfile

from sklearn.model_selection   import train_test_split, cross_val_score,RepeatedKFold
from sklearn.linear_model      import LinearRegression,Ridge,Lasso
from sklearn.model_selection   import GridSearchCV
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.metrics           import mean_squared_error, r2_score
from sklearn.preprocessing     import StandardScaler 

random_seed = 42

# %% [markdown]
# ## **Prelude: Download the Preprocessed Ames Housing Dataset**
#
# I have stored the dataset as a zipped directory containing the following four files from an 80%-20% split of the Ames dataset after preprocessing (as done in the last homework):
#
# - `X_train.csv`
# - `y_train.csv`
# - `X_test.csv`
# - `y_test.csv`
#
# **TODO:** Run the following cell to download and extract the dataset into the current working directory of this notebook.
# Alternatively, you can manually download the zip file from the provided URL, extract it, and place the files in the same directory as your notebook.
#
# > ⚠️ **Important:**
# > DO NOT use your own version of these datasets from the last homework. The autograder expects the exact split provided in my files for both training and testing sets. Using any other split will result in incorrect results during grading.

# %%
# Download the Ames Housing Dataset from Snyder's web site

# URL to the zip file
zip_url = "https://www.cs.bu.edu/fac/snyder/cs505/Data/ames_housing.zip"

try:
    response = requests.get(zip_url)
    response.raise_for_status()  # Raise an error for bad status codes
    with zipfile.ZipFile(io.BytesIO(response.content)) as zipf:
        zipf.extractall("Ames_Dataset_HW")
    print("Files downloaded and extracted successfully.")
except requests.exceptions.RequestException as e:
    print(f"Error downloading the file: {e}")


DATA_DIR = "Ames_Dataset_HW"

X_train = pd.read_csv(f"{DATA_DIR}/X_train.csv")
X_test  = pd.read_csv(f"{DATA_DIR}/X_test.csv")

y_train = pd.read_csv(f"{DATA_DIR}/y_train.csv").squeeze("columns")
y_test  = pd.read_csv(f"{DATA_DIR}/y_test.csv").squeeze("columns")

print("Training and testing datasets loaded successfully.")
# Out:
# Files downloaded and extracted successfully.
# Training and testing datasets loaded successfully.

# %% [markdown]
# ## **Problem One: Forward Selection with the Ames Dataset**
#
# For our first experiment we will apply the forward feature selection algorithm to the dataset. Follow these steps, using the notebook from this week's video lesson as a resource as necessary.
#
# **If you have not looked at the video yet, please do it now before continuing.**
#
# **Steps to Follow:**
# 1. **Observe** that we have provided the `forward_feature_selection` algorithm from the video notebook for you to use.
#
# 2. **Copy** from the video notebook into the cell indicated below the code that runs forward feature selection and generates a plot (excluding the part that prints the test MSE--we'll do that at the end of this homework). Or write your own version!
#
# 3. **Modify** this code to display the **Root Mean Squared Error (RMSE)** instead of MSE.
#    - *Remember*: RMSE is the square root of MSE, which provides results in dollars rather than dollars squared, making the metric more interpretable.
#    - Both the plot of RMSE vs. the number of selected features and the printout of the Best CV Score should use RMSE.
#
# 4. **Run** the code on `X_train` and `y_train` (keeping all default settings) to:
#    - Generate the plot of **Root Mean Squared Error (RMSE)** vs. **Features Added**, and
#    - Print the **Best Feature Set** found and the **Best CV RMSE Score**.
#
# **Hints:**
# - The feature names will be more legible if you increase the size of the plot and change the angle and size of the xticks, e.g.,
#
#         plt.xticks(range(1, len(selected_features_forward) + 1), selected_features_forward, rotation=60, ha='right', fontsize=6)
#
# - You may wish to change the scale of the y-axis to better see the behavior around the minimum point.

# %%
# Forward Feature Selection

def forward_feature_selection(X, y, model, 
                              scoring='neg_mean_squared_error', 
                              cv = 5, 
                              tol=None,               # None = no delta cutoff
                                                      # use 0.0 for "no further improvements"
                                                      # and 1e-4 for "point of diminishing returns"                                      
                              max_features=None,      # None = use all features
                              n_jobs=-1,
                              verbose=False
                             ):
    selected_features = []                            # List to store the order of features selected
    remaining_features = list(X.columns)              # Features not yet selected
    best_scores = []                                  # List to store the CV score after each feature addition
    previous_score = float('inf')                     # Initialize previous score for improvement comparison

    # Track the best subset of features and its corresponding score
    
    best_feature_set = None                           # Best combination of features found so far
    best_score = float('inf')                         # Best CV score observed so far
    
    while remaining_features:
        scores = {}                                   # Dictionary to hold CV scores for each candidate feature
        for feature in remaining_features:
            current_features = selected_features + [feature]
            
            # Compute the CV score for the current set of features (negated MSE, so lower is better)
            cv_score = -cross_val_score(model, X[current_features], y, 
                                        scoring=scoring, cv=cv, n_jobs=n_jobs
                                       ).mean()
            scores[feature] = cv_score

        # Select the feature that minimizes the CV score
        best_feature = min(scores, key=scores.get)
        current_score = scores[best_feature]
            
        # Check if the improvement is significant based on the tolerance (tol)
        if tol is not None and previous_score - current_score < tol:
            if verbose:
                print("Stopping early due to minimal improvement.")
            break

        # Add the best feature to the selected list and update score trackers
        selected_features.append(best_feature)
        best_scores.append(current_score)
        remaining_features.remove(best_feature)
        previous_score = current_score

        if verbose:
            print(f"\nFeatures: {selected_features[-3:]}, CV Score (MSE): {current_score:.4f}")
        
        # Update the best subset if the current score is better than the best so far
        if current_score < best_score:
            best_score = current_score
            best_feature_set = selected_features.copy()
        
        # Check if the maximum number of features has been reached
        if max_features is not None and len(selected_features) >= max_features:
            break

    return (
        selected_features,      # List of features in the order they were selected (this will be ALL features if max_features == None
        best_scores,            # List of cross-validation scores corresponding to each addition in the previous list
        best_feature_set,       # The subset of features that achieved the best CV score.
        best_score              # The best CV score
    )

# %%
# Your code here:  Run Forward Feature Selection, plot the results, and print out the Best Feature Set and the Best CV Score found. 
# Forward Feature Selection

def forward_feature_selection(X, y, model, 
                              scoring='neg_root_mean_squared_error', 
                              cv = 5, 
                              tol=None,               # None = no delta cutoff
                                                      # use 0.0 for "no further improvements"
                                                      # and 1e-4 for "point of diminishing returns"                                      
                              max_features=None,      # None = use all features
                              n_jobs=-1,
                              verbose=False
                             ):
    selected_features = []                            # List to store the order of features selected
    remaining_features = list(X.columns)              # Features not yet selected
    best_scores = []                                  # List to store the CV score after each feature addition
    previous_score = float('inf')                     # Initialize previous score for improvement comparison

    # Track the best subset of features and its corresponding score
    
    best_feature_set = None                           # Best combination of features found so far
    best_score = float('inf')                         # Best CV score observed so far
    
    while remaining_features:
        scores = {}                                   # Dictionary to hold CV scores for each candidate feature
        for feature in remaining_features:
            current_features = selected_features + [feature]
            
            # Compute the CV score for the current set of features (negated MSE, so lower is better)
            cv_score = -cross_val_score(model, X[current_features], y, 
                                        scoring=scoring, cv=cv, n_jobs=n_jobs
                                       ).mean()
            scores[feature] = cv_score

        # Select the feature that minimizes the CV score
        best_feature = min(scores, key=scores.get)
        current_score = scores[best_feature]
            
        # Check if the improvement is significant based on the tolerance (tol)
        if tol is not None and previous_score - current_score < tol:
            if verbose:
                print("Stopping early due to minimal improvement.")
            break

        # Add the best feature to the selected list and update score trackers
        selected_features.append(best_feature)
        best_scores.append(current_score)
        remaining_features.remove(best_feature)
        previous_score = current_score

        if verbose:
            print(f"\nFeatures: {selected_features[-3:]}, CV Score (MSE): {current_score:.4f}")
        
        # Update the best subset if the current score is better than the best so far
        if current_score < best_score:
            best_score = current_score
            best_feature_set = selected_features.copy()
        
        # Check if the maximum number of features has been reached
        if max_features is not None and len(selected_features) >= max_features:
            break

    return (
        len(best_feature_set),
        selected_features,      # List of features in the order they were selected (this will be ALL features if max_features == None
        best_scores,            # List of cross-validation scores corresponding to each addition in the previous list
        best_feature_set,       # The subset of features that achieved the best CV score.
        best_score,              # The best CV score
    )

# %%
# Run forward selection 
X = X_train
y = y_train
model = LinearRegression()

feature_set_length, selected_features, best_scores, best_feature_set, best_score = forward_feature_selection(X, y, model)

plt.figure(figsize=(16, 5))
plt.plot(range(1, len(best_scores) + 1), best_scores, marker='o')
plt.xlabel("Feature Added (in order)")
plt.ylabel("CV RMSE")
plt.title("Forward Selection: CV RMSE vs Feature Added")

plt.xticks(
    range(1, len(selected_features) + 1),
    selected_features,
    rotation=60,
    ha='right',
    fontsize=6
)

# highlight lowest RMSE point
best_idx = int(np.argmin(best_scores))
best_x = best_idx + 1
best_y = best_scores[best_idx]

plt.scatter(best_x, best_y, color='red', s=120, zorder=5, label='Best')

plt.annotate(
    f"Min RMSE: {best_y:.0f}",
    (best_x, best_y),
    textcoords="offset points",
    xytext=(0,10),
    ha='center',
    color='red',
    fontsize=9
)

# zoom y-axis around minimum if you want
min_rmse = min(best_scores)
plt.ylim(min_rmse - 2000, min_rmse + 2000)

plt.legend()
plt.tight_layout()
plt.show()

print(f"Best Feature Length: {feature_set_length}")
# Out:
# Best Feature Length: 42

# %% [markdown]
# ### Problem One Graded Questions
#
# Assign `a1a` to the number of features in the best feature set found

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a1a = 42                     # replace 0 with an expression

# %%
# Do not change this cell in any way

print(f"a1a = {a1a}")
# Out:
# a1a = 42

# %% [markdown]
# Assign `a1b` to the best CV RMSE score found.

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a1b = 30038.63819415708                     # replace 0 with an expression

# %%
# Do not change this cell in any way

print(f"a1b = ${a1b:,.2f}")
# Out:
# a1b = $30,038.64

# %% [markdown]
# ## **Problem Two: Backward Selection with the Ames Dataset**
#
# Now, repeat the same process as in Problem One, but using the `backward_feature_selection` algorithm from this week’s video notebook. Again, we will use 5-Fold CV scoring.
#
# **Steps to Follow:**
# 1. **Observe** that we have provided the `backward_feature_selection` algorithm from this week's video notebook for you to use.
# 2. **Run** the backward selection algorithm on the Ames dataset (`X_train` and `y_train`).
# 3. **Plot** the results: Display the Root Mean Squared Error (RMSE) vs. the features removed by the algorithm.
# 4. **Print** the Best Feature Set found by backward selection and the corresponding best CV RMSE Score.

# %%
# Backward Feature Selection

def backward_feature_selection(X, y, model, 
                               scoring='neg_root_mean_squared_error', 
                               cv = 5, 
                               tol=None,               # None = no delta cutoff
                                                       # use 0.0 for "no further improvements"
                                                       # and 1e-4 for "point of diminishing returns"                                      
                               max_features=None,      # If None, remove features until only 1 remains
                                                       # Otherwise, stop when this many features remain
                               n_jobs=-1,
                               verbose=True
                              ):
    
    # Helper function to compute CV score using LinearRegression
    def cv_score(features):
        return -cross_val_score(model, X[features], y, 
                                scoring=scoring, cv=cv, 
                                n_jobs=n_jobs          ).mean()
    
    # Start with all features (using a list for easier manipulation)
    features_remaining = list(X.columns)
    
    # Compute initial CV score with the full feature set
    initial_score = cv_score(features_remaining)
    
    # Initialize tracking variables
    best_score        = initial_score                # Best (lowest) CV score observed so far
    best_feature_set  = features_remaining.copy()    # Feature set corresponding to best_score
    selected_features = ['NONE']                     # List to record the order in which features are removed
    best_scores       = [initial_score]              # List to record the CV score after each removal (starting with full set)
    
    if verbose:
        print("Start with full set of features:")
        print(f'{features_remaining}  CV score (MSE): {np.around(initial_score, 4)}\n')
    
    # Determine the target number of features to keep:
    # For backward elimination, if max_features is None, we remove until 1 feature remains.
    target_feature_count = 1 if max_features is None else max_features
    
    prev_score = initial_score
    round_num = 1
    # Continue removing features until we reach the target count
    while len(features_remaining) > target_feature_count:
        if verbose:
            print(f'Round {round_num}:')
            
        # Initialize variables to track the best removal in this round
        lowest_score = float('inf')
        feature_to_remove = None
        best_new_features = None
        
        # Try removing each feature one at a time
        for feature in features_remaining:
            new_feature_set = features_remaining.copy()
            new_feature_set.remove(feature)
            new_score = cv_score(new_feature_set)
            if verbose:
                print('Trying removal of:',feature, np.around(new_score, 4))
            if new_score < lowest_score:
                lowest_score = new_score
                feature_to_remove = feature
                best_new_features = new_feature_set
        
        # Check if improvement is significant enough (if tol is set)
        if tol is not None and (prev_score - lowest_score) < tol:
            if verbose:
                print("\nStopping early due to minimal improvement.")
            break
        
        # Update the best score and feature set if current removal improves performance
        if lowest_score < best_score:
            best_score = lowest_score
            best_feature_set = best_new_features.copy()
        
        # Update trackers for this round
        prev_score = lowest_score
        features_remaining = best_new_features
        selected_features.append(feature_to_remove)
        best_scores.append(lowest_score)
        
        if verbose:
            print(f'\nRemoving {feature_to_remove}:  CV score (MSE) {np.around(lowest_score, 4)}\n')
        round_num += 1

    return (
        selected_features,      # Order in which features were removed
        best_scores,            # CV scores after each removal step
        best_feature_set,       # Feature set that achieved the best CV score
        best_score              # Best (lowest) CV score
    )


X = X_train
y = y_train
model = LinearRegression()

selected_features, best_scores, best_feature_set, best_score = backward_feature_selection(X, y, model)
# Out:
# Start with full set of features:
# ['MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area', 'Street', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual', 'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style', 'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF', 'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional', 'Fireplaces', 'Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual', 'Garage Cond', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type', 'Sale Condition']  CV score (MSE): 31176.2714
#
# Round 1:
# Trying removal of: MS SubClass 31246.5904
# Trying removal of: MS Zoning 31180.3645
# Trying removal of: Lot Frontage 31112.3957
# Trying removal of: Lot Area 444617503893646.4
# Trying removal of: Street 31202.0551
# Trying removal of: Lot Shape 31188.2439
# Trying removal of: Land Contour 31193.4489
# Trying removal of: Utilities 31146.4459
# Trying removal of: Lot Config 31161.9939
# Trying removal of: Land Slope 31188.9751
# Trying removal of: Neighborhood 31230.1687
# Trying removal of: Condition 1 31163.0937
# Trying removal of: Condition 2 31179.9069
# Trying removal of: Bldg Type 31207.126
# Trying removal of: House Style 31221.1284
# Trying removal of: Overall Qual 32743.3598
# Trying removal of: Overall Cond 31388.8834
# Trying removal of: Year Built 31282.8849
# Trying removal of: Year Remod/Add 31168.0965
# Trying removal of: Roof Style 31240.207
# Trying removal of: Roof Matl 31110.57
# Trying removal of: Exterior 1st 31248.5288
# Trying removal of: Exterior 2nd 31181.1812
# Trying removal of: Mas Vnr Area 31294.6181
# Trying removal of: Exter Qual 31597.6331
# Trying removal of: Exter Cond 31157.0419
# Trying removal of: Foundation 31170.1389
# Trying removal of: Bsmt Qual 31384.4152
# Trying removal of: Bsmt Cond 31180.3394
# Trying removal of: Bsmt Exposure 31465.0661
# Trying removal of: BsmtFin Type 1 31225.9004
# Trying removal of: BsmtFin SF 1 31174.4586
# Trying removal of: BsmtFin Type 2 31154.6825
# Trying removal of: BsmtFin SF 2 31174.9512
# Trying removal of: Bsmt Unf SF 31175.2829
# Trying removal of: Total Bsmt SF 31175.8433
# Trying removal of: Heating 31160.58
# Trying removal of: Heating QC 31179.9977
# Trying removal of: Central Air 31168.3362
# Trying removal of: Electrical 31172.2274
# Trying removal of: 1st Flr SF 31176.2714
# Trying removal of: 2nd Flr SF 31176.2714
# Trying removal of: Low Qual Fin SF 31176.2714
# Trying removal of: Gr Liv Area 31176.2714
# Trying removal of: Bsmt Full Bath 31222.6944
# Trying removal of: Bsmt Half Bath 31146.1633
# Trying removal of: Full Bath 31165.5497
# Trying removal of: Half Bath 31173.101
# Trying removal of: Bsmt Exposure 30525.5196
# Trying removal of: BsmtFin Type 1 30270.0641
# Trying removal of: Gr Liv Area 35290.8603
# Trying removal of: Bsmt Full Bath 30548.6446
# Trying removal of: Kitchen AbvGr 30213.7804
# Trying removal of: Kitchen Qual 30437.6336
# Trying removal of: Functional 30309.1769
# Trying removal of: Fireplaces 30290.0588
# Trying removal of: Garage Cars 30422.9423
# Trying removal of: Wood Deck SF 30204.8309
# Trying removal of: Screen Porch 30435.1181
# Trying removal of: Yr Sold 30233.1338
# Trying removal of: Sale Condition 30298.7803
#
# Removing Wood Deck SF:  CV score (MSE) 30204.8309
#
# Round 51:
# Trying removal of: MS SubClass 30808.9164
# Trying removal of: Lot Area 30484.6477
# Trying removal of: Street 30252.9245
# Trying removal of: Neighborhood 30276.2469
# Trying removal of: House Style 30303.839
# Trying removal of: Overall Qual 31872.174
# Trying removal of: Overall Cond 30528.4276
# Trying removal of: Year Built 30617.0613
# Trying removal of: Mas Vnr Area 30422.383
# Trying removal of: Exter Qual 30716.7157
# Trying removal of: Bsmt Qual 30484.0831
# Trying removal of: Bsmt Exposure 30595.4596
# Trying removal of: BsmtFin Type 1 30317.5122
# Trying removal of: Gr Liv Area 35513.1306
# Trying removal of: Bsmt Full Bath 30606.5692
# Trying removal of: Kitchen AbvGr 30261.1967
# Trying removal of: Kitchen Qual 30482.4673
# Trying removal of: Functional 30340.4558
# Trying removal of: Fireplaces 30345.2967
# Trying removal of: Garage Cars 30469.2659
# Trying removal of: Screen Porch 30456.8094
# Trying removal of: Yr Sold 30270.5095
# Trying removal of: Sale Condition 30338.893
#
# Removing Street:  CV score (MSE) 30252.9245
#
# Round 52:
# Trying removal of: MS SubClass 30878.9218
# Trying removal of: Lot Area 30487.0315
# Trying removal of: Neighborhood 30323.4186
# Trying removal of: House Style 30354.1682
# Trying removal of: Overall Qual 31942.5728
# Trying removal of: Overall Cond 30581.2095
# Trying removal of: Year Built 30686.4907
# Trying removal of: Mas Vnr Area 30468.9315
# Trying removal of: Exter Qual 30730.6196
# Trying removal of: Bsmt Qual 30529.0564
# Trying removal of: Bsmt Exposure 30633.7056
# Trying removal of: BsmtFin Type 1 30369.3132
# Trying removal of: Gr Liv Area 35693.6403
# Trying removal of: Bsmt Full Bath 30650.657
# Trying removal of: Kitchen AbvGr 30306.6678
# Trying removal of: Kitchen Qual 30536.8649
# Trying removal of: Functional 30393.6581
# Trying removal of: Fireplaces 30395.9332
# Trying removal of: Garage Cars 30512.3161
# Trying removal of: Screen Porch 30499.7177
# Trying removal of: Yr Sold 30322.7304
# Trying removal of: Sale Condition 30388.9901
#
# Removing Kitchen AbvGr:  CV score (MSE) 30306.6678
#
# Round 53:
# Trying removal of: MS SubClass 31089.9054
# Trying removal of: Lot Area 30543.7943
# Trying removal of: Neighborhood 30367.2151
# Trying removal of: House Style 30390.5077
# Trying removal of: Overall Qual 32131.8629
# Trying removal of: Overall Cond 30654.9592
# Trying removal of: Year Built 30737.6856
# Trying removal of: Kitchen Qual 30850.1276
# Trying removal of: Functional 30644.1824
# Trying removal of: Fireplaces 30656.2245
# Trying removal of: Garage Cars 30785.7065
# Trying removal of: Screen Porch 30779.1698
# Trying removal of: Sale Condition 30663.1353
#
# Removing Functional:  CV score (MSE) 30644.1824
#
# Round 57:
# Trying removal of: MS SubClass 31732.5496
# Trying removal of: Lot Area 30894.7787
# Trying removal of: Overall Qual 32817.8477
# Trying removal of: Overall Cond 30979.5775
# Trying removal of: Year Built 31028.8104
# Trying removal of: Mas Vnr Area 30888.7935
# Trying removal of: Exter Qual 31119.7489
# Trying removal of: Bsmt Qual 30930.4756
# Trying removal of: Bsmt Exposure 30970.2692
# Trying removal of: BsmtFin Type 1 30772.8623
# Trying removal of: Gr Liv Area 36072.0917
# Trying removal of: Bsmt Full Bath 31036.5074
# Trying removal of: Kitchen Qual 30974.5325
# Trying removal of: Fireplaces 30755.4377
# Trying removal of: Garage Cars 30891.461
# Trying removal of: Screen Porch 30904.4575
# Trying removal of: Sale Condition 30783.1935
#
# Removing Fireplaces:  CV score (MSE) 30755.4377
#
# Round 58:
# Trying removal of: MS SubClass 31918.6877
# Trying removal of: Lot Area 31077.5219
# Trying removal of: Overall Qual 33199.5511
# Trying removal of: Overall Cond 31075.1602
# Trying removal of: Year Built 31110.6195
# Trying removal of: Mas Vnr Area 31030.5242
# Trying removal of: Exter Qual 31205.3462
# Trying removal of: Bsmt Qual 31031.9603
# Trying removal of: Bsmt Exposure 31123.3672
# Trying removal of: BsmtFin Type 1 30920.7101
# Trying removal of: Gr Liv Area 36956.3245
# Trying removal of: Bsmt Full Bath 31165.9835
# Trying removal of: Kitchen Qual 31062.2345
# Trying removal of: Garage Cars 31014.0921
# Trying removal of: Screen Porch 31061.1013
# Trying removal of: Sale Condition 30899.6158
#
# Removing Sale Condition:  CV score (MSE) 30899.6158
#
# Round 59:
# Trying removal of: MS SubClass 32067.0329
# Trying removal of: Lot Area 31215.5615
# Trying removal of: Overall Qual 33369.0168
# Trying removal of: Overall Cond 31290.5032
# Trying removal of: Year Built 31305.9324
# Trying removal of: Mas Vnr Area 31168.6374
# Trying removal of: Exter Qual 31366.2517
# Trying removal of: Bsmt Qual 31197.7139
# Trying removal of: Bsmt Exposure 31253.9917
# Trying removal of: BsmtFin Type 1 31056.1796
# Trying removal of: Gr Liv Area 36987.4293
# Trying removal of: Bsmt Full Bath 31303.3171
# Trying removal of: Kitchen Qual 31213.3887
# Trying removal of: Garage Cars 31192.6388
# Trying removal of: Screen Porch 31188.6194
#
# Removing BsmtFin Type 1:  CV score (MSE) 31056.1796
#
# Round 60:
# Trying removal of: MS SubClass 32213.5299
# Trying removal of: Lot Area 31380.8224
# Trying removal of: Overall Qual 33427.6347
# Trying removal of: Overall Cond 31533.8204
# Trying removal of: Year Built 31599.0965
# Trying removal of: Mas Vnr Area 31359.7196
# Trying removal of: Exter Qual 31498.2167
# Trying removal of: Bsmt Qual 31304.1468
# Trying removal of: Bsmt Exposure 31430.5145
# Trying removal of: Gr Liv Area 37046.5076
# Trying removal of: Bsmt Full Bath 31861.3261
# Trying removal of: Kitchen Qual 31360.8984
# Trying removal of: Garage Cars 31353.4495
# Trying removal of: Screen Porch 31362.4515
#
# Removing Bsmt Qual:  CV score (MSE) 31304.1468
#
# Round 61:
# Trying removal of: MS SubClass 32399.681
# Trying removal of: Lot Area 31621.1756
# Trying removal of: Overall Qual 33937.9904
# Trying removal of: Overall Cond 31717.4202
# Trying removal of: Year Built 32093.2811
# Trying removal of: Mas Vnr Area 31579.5105
# Trying removal of: Exter Qual 31936.1978
# Trying removal of: Bsmt Exposure 31746.1
# Trying removal of: Gr Liv Area 37330.9747
# Trying removal of: Bsmt Full Bath 32151.8544
# Trying removal of: Kitchen Qual 31660.0124
# Trying removal of: Garage Cars 31668.1724
# Trying removal of: Screen Porch 31584.0855
#
# Removing Mas Vnr Area:  CV score (MSE) 31579.5105
#
# Round 62:
# Trying removal of: MS SubClass 32715.9349
# Trying removal of: Lot Area 31890.2038
# Trying removal of: Overall Qual 34352.4372
# Trying removal of: Overall Cond 31953.773
# Trying removal of: Year Built 32403.5006
# Trying removal of: Exter Qual 32307.3475
# Trying removal of: Bsmt Exposure 32060.2924
# Trying removal of: Gr Liv Area 38242.2681
# Trying removal of: Bsmt Full Bath 32474.3099
# Trying removal of: Kitchen Qual 31905.6827
# Trying removal of: Garage Cars 31987.2111
# Trying removal of: Screen Porch 31886.7203
#
# Removing Screen Porch:  CV score (MSE) 31886.7203
#
# Round 63:
# Trying removal of: MS SubClass 33101.1626
# Trying removal of: Lot Area 32188.5724
# Trying removal of: Overall Qual 34662.2324
# Trying removal of: Overall Cond 32268.4729
# Trying removal of: Year Built 32650.0887
# Trying removal of: Exter Qual 32584.4996
# Trying removal of: Bsmt Exposure 32378.9633
# Trying removal of: Gr Liv Area 38768.637
# Trying removal of: Bsmt Full Bath 32832.0321
# Trying removal of: Kitchen Qual 32214.596
# Trying removal of: Garage Cars 32297.3972
#
# Removing Lot Area:  CV score (MSE) 32188.5724
#
# Round 64:
# Trying removal of: MS SubClass 33655.1364
# Trying removal of: Overall Qual 34792.7103
# Trying removal of: Overall Cond 32548.2967
# Trying removal of: Year Built 32896.7809
# Trying removal of: Exter Qual 32857.7323
# Trying removal of: Bsmt Exposure 32776.2895
# Trying removal of: Gr Liv Area 39681.9803
# Trying removal of: Bsmt Full Bath 33253.8962
# Trying removal of: Kitchen Qual 32485.1355
# Trying removal of: Garage Cars 32658.739
#
# Removing Kitchen Qual:  CV score (MSE) 32485.1355
#
# Round 65:
# Trying removal of: MS SubClass 34006.9637
# Trying removal of: Overall Qual 35393.5244
# Trying removal of: Overall Cond 32898.4773
# Trying removal of: Year Built 33262.8178
# Trying removal of: Exter Qual 33867.0288
# Trying removal of: Bsmt Exposure 33081.1484
# Trying removal of: Gr Liv Area 40184.0658
# Trying removal of: Bsmt Full Bath 33592.0339
# Trying removal of: Garage Cars 32949.2094
#
# Removing Overall Cond:  CV score (MSE) 32898.4773
#
# Round 66:
# Trying removal of: MS SubClass 34480.1462
# Trying removal of: Overall Qual 36436.6067
# Trying removal of: Year Built 33363.8714
# Trying removal of: Exter Qual 34163.3296
# Trying removal of: Bsmt Exposure 33493.7441
# Trying removal of: Gr Liv Area 40226.2026
# Trying removal of: Bsmt Full Bath 34017.3176
# Trying removal of: Garage Cars 33335.002
#
# Removing Garage Cars:  CV score (MSE) 33335.002
#
# Round 67:
# Trying removal of: MS SubClass 35129.7394
# Trying removal of: Overall Qual 37396.8285
# Trying removal of: Year Built 34201.5747
# Trying removal of: Exter Qual 34639.5489
# Trying removal of: Bsmt Exposure 33995.6231
# Trying removal of: Gr Liv Area 42257.2157
# Trying removal of: Bsmt Full Bath 34513.7232
#
# Removing Bsmt Exposure:  CV score (MSE) 33995.6231
#
# Round 68:
# Trying removal of: MS SubClass 35602.6096
# Trying removal of: Overall Qual 38314.2336
# Trying removal of: Year Built 35082.1521
# Trying removal of: Exter Qual 35338.1577
# Trying removal of: Gr Liv Area 42515.6391
# Trying removal of: Bsmt Full Bath 35642.7983
#
# Removing Year Built:  CV score (MSE) 35082.1521
#
# Round 69:
# Trying removal of: MS SubClass 36583.3904
# Trying removal of: Overall Qual 42291.8192
# Trying removal of: Exter Qual 36919.4335
# Trying removal of: Gr Liv Area 42683.9951
# Trying removal of: Bsmt Full Bath 37127.8697
#
# Removing MS SubClass:  CV score (MSE) 36583.3904
#
# Round 70:
# Trying removal of: Overall Qual 43464.6319
# Trying removal of: Exter Qual 38372.2234
# Trying removal of: Gr Liv Area 43561.9092
# Trying removal of: Bsmt Full Bath 38502.3434
#
# Removing Exter Qual:  CV score (MSE) 38372.2234
#
# Round 71:
# Trying removal of: Overall Qual 51922.6377
# Trying removal of: Gr Liv Area 45381.348
# Trying removal of: Bsmt Full Bath 40370.6105
#
# Removing Bsmt Full Bath:  CV score (MSE) 40370.6105
#
# Round 72:
# Trying removal of: Overall Qual 55270.9395
# Trying removal of: Gr Liv Area 46750.5331
#
# Removing Gr Liv Area:  CV score (MSE) 46750.5331
# Best RMSE: 30006.539615409944
# Best #features: 42

# %%
# Your code here:  Run Backward Feature Selection, plot the results, and print out the Best Feature Set and the Best CV RMSE Score found. 
rmse = best_scores 

# x-axis: number of features remaining at each step
n_start = X.shape[1]
n_remaining = list(range(n_start, n_start - len(rmse), -1))  # e.g. 80,79,78,...

plt.figure(figsize=(10, 5))
plt.plot(n_remaining, rmse, marker='o')
plt.gca().invert_xaxis()  # optional: shows fewer features as you move right
plt.xlabel("Number of Features Remaining")
plt.ylabel("CV RMSE")
plt.title("Backward Selection: CV RMSE vs Features Remaining")

# highlight minimum point
best_idx = int(np.argmin(rmse))
best_x = n_remaining[best_idx]
best_y = rmse[best_idx]

plt.scatter(best_x, best_y, color='red', s=120, zorder=5, label="Best")

plt.annotate(
    f"Min RMSE: {best_y:.0f}\nFeatures remaining: {best_x}",
    (best_x, best_y),
    textcoords="offset points",
    xytext=(10, 10),
    ha="left",
    color="red",
    fontsize=9
)

plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

print("Best RMSE:", best_score)
print("Best #features:", len(best_feature_set))
# Out:
# Best RMSE: 30006.539615409944
# Best #features: 42

# %% [markdown]
# ### Problem Two Graded Questions
#
# Assign `a2a` to the number of features in the best feature set found

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a2a = 42                     # replace 0 with an expression

# %%
# Do not change this cell in any way

print(f"a2a = {a2a}")
# Out:
# a2a = 42

# %% [markdown]
# Assign `a2b` to the best CV RMSE score found.

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a2b = 30006.539615409944                     # replace 0 with an expression

# %%
# Do not change this cell in any way

print(f"a2b = ${a2b:,.2f}")
# Out:
# a2b = $30,006.54

# %% [markdown]
# ## **Problem Three: Ridge Regression on the Ames Housing Dataset**
#
# In this problem, we will apply Ridge Regression to the Ames Housing dataset. Ridge Regression includes a hyperparameter $\alpha$ that controls the strength of the regularization penalty, which helps prevent overfitting by constraining the growth of the model’s coefficients. A higher $\alpha$ penalizes large coefficients more, while a lower $\alpha$ allows them to grow larger.
#
# When creating the model, the parameter must be specified, for example:
#
# ```python
# ridge_model = Ridge(alpha=100)
# ```
#
# This introduces another instance of the model selection problem: we must determine the value of $\alpha$ that yields the best CV RMSE score.
#
# **Steps to Follow:**
#
# 1. **Standardize the Data:**
#    Ridge regression is sensitive to the scale of the features, so we will use `StandardScaler` to standardize the feature set to have a mean of 0 and a standard deviation of 1 before training and testing. Note that the target variable does **not** need to be scaled.
#
# 2. **Perform Cross-Validation Over a Range of Alpha Values:**
#    For each $\alpha \in \{100, 110, 120, \dots, 500\}$, calculate the cross-validation RMSE score for the model using 5-Fold CV scoring.
#
# 3. **Visualize the Results:**
#    Plot the CV RMSE scores against the $\alpha$ values.
#
# 4. **Identify the Best Alpha:**
#    Determine the $\alpha$ that results in the minimum CV RMSE Score and print it out, along with the score.
#
# **Tip:** It would be an *excellent* idea to add the suffix `_scaled` to any set to which you apply scaling.

# %%
# Your code here
n_jobs = -1
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

X = X_train_scaled
y = y_train

cv = 5
alphas = np.arange(100, 501, 10)

def cv_rmse_for_alpha(alpha):
    model = Ridge(alpha=alpha)
    rmse = -cross_val_score(
        model,
        X,
        y,
        scoring="neg_root_mean_squared_error",
        cv=cv,
        n_jobs = n_jobs
    ).mean()
    return rmse

cv_rmses = [cv_rmse_for_alpha(a) for a in alphas]

# %%
# plot RSMEs
best_idx = int(np.argmin(cv_rmses))
best_alpha = alphas[best_idx]
best_rmse = cv_rmses[best_idx]

plt.figure(figsize=(10, 5))
plt.plot(alphas, cv_rmses, marker='o')
plt.xlabel("Alpha (α)")
plt.ylabel("CV RMSE")
plt.title("Ridge Regression: CV RMSE vs Alpha")

# highlight best alpha
plt.scatter(best_alpha, best_rmse, color="red", s=120, zorder=5, label="Best")

plt.annotate(
    f"Best α = {best_alpha}\nRMSE = {best_rmse:.0f}",
    (best_alpha, best_rmse),
    textcoords="offset points",
    xytext=(10, 10),
    ha="left",
    color="red",
    fontsize=9
)

plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

print(f"Best Alpha:{best_alpha}")
print(f"Best CV RMSE:{best_rmse}")
# Out:
# Best Alpha:270
# Best CV RMSE:30886.225320845366

# %% [markdown]
# ### Problem Three Graded Answers
#
# Set `a3a` to the alpha determined to have the minimum CV RMSE score.

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a3a = 270                     # replace 0 with an expression

# %%
# Do not change this cell in any way. 

print(f"a3a = {a3a}")
# Out:
# a3a = 270

# %% [markdown]
# Set `a3b` to the CV score found at that alpha.

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a3b = 30886.225320845366                     # replace 0 with an expression

# %%
# Do not change this cell in any way. 

print(f"a3b = ${a3b:,.2f}")
# Out:
# a3b = $30,886.23

# %% [markdown]
# ## **Problem Four: Evaluate Your Best Model**
#
# In this final problem, you will identify the model with the best cross-validation RMSE score and evaluate its performance on the held-out test set.
#
# #### **Steps to Follow:**
#
# 1. **Identify the Best Model:**
#    From your previous results, select the model that achieved the lowest CV RMSE score.
#
# 3. **Train and Test the Selected Model:**
#    - For Forward or Backward Feature Selection:  Train a Linear Regression model using `X_train` **restricted to the selected best feature set**, and evaluate it on `X_test` restricted to the same feature set.
#    - For Ridge Regression:   Train a Ridge Regression model using the best alpha found from cross-validation, with `StandardScaler` applied to both `X_train` and `X_test` before training and testing.
#
# 4. **Report Your Results:**
#    Print the name of the best model and the test RMSE in dollars.

# %%
# Your code here
best_forward = a1b
best_backward = a2b
best_ridge = a3b


print(f"Best forward:{best_forward}")
print(f"Best backward:{best_backward}")
print(f"Best ridge:{best_ridge}")

best_overall = min(best_forward,best_backward,best_ridge)
print(f"Best Overall:{best_overall}")
# Out:
# Best forward:30038.63819415708
# Best backward:30006.539615409944
# Best ridge:30886.225320845366
# Best Overall:30006.539615409944

# %% [markdown]
# ### Problem Four Graded Answers
#
# Set `a4a` to the best model, according to the CV RMSE score.
#
# - 1 = Forward Selection
# - 2 = Backward Selection
# - 3 = Ridge Regression

# %%
# Your answer here

a4a = 2                     # replace 0 with one of [1,2,3]

# %%
# Do not change this cell in any way. 

print(f"a4a = {a4a}")
# Out:
# a4a = 2

# %% [markdown]
# Set `a4b` to the test RMSE for the best model.

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a4b =  30006.539615409944                    # replace 0 with an expression

# %%
# Do not change this cell in any way. 

print(f"a4b = ${a4b:,.2f}")
# Out:
# a4b = $30,006.54

# %% [markdown]
# ### Appendix: Final "Pause and Ponder" issue (ungraded) ....
#
# Why didn't we evaluate *all* the models on the test set and compare them?
#
# ### Some answers...
#
# It’s tempting to reconsider your choice based on test scores, but this violates the core principle of not "training to the test." That’s why we deliberately avoided evaluating all models on the test set.
#
# The test set doesn’t influence model training; it serves as a final, unbiased check on how well your chosen model generalizes to unseen data, ensuring that your selection process wasn’t overly optimistic.
#
# A natural **next question** is: Why use a test set at all? Beyond being an industry-standard practice that simulates the real world—where you can’t adjust your model after deployment—consider:
#
# - **Validating your workflow:** A strong test score confirms that your model selection process (feature selection, hyperparameter tuning, etc.) was sound. A poor test score despite good cross-validation results may indicate overfitting or a flawed approach.
#
# - **Guarding against over-optimism:** Cross-validation can be slightly optimistic, especially with limited data or repeated trials. The test set provides a final safeguard against relying on an overly tuned model.
